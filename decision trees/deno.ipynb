# %%
import seaborn as sns
import numpy as np
df = sns.load_dataset('penguins')

# %%
np.unique(df['species'], return_counts = True)
df[df['flipper_length_mm'] >= 206.5]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 95      Adelie      Dream            40.8           18.9              208.0
# 129     Adelie  Torgersen            44.1           18.0              210.0
# 189  Chinstrap      Dream            52.0           20.7              210.0
# 192  Chinstrap      Dream            49.0           19.5              210.0
# 199  Chinstrap      Dream            49.0           19.6              212.0
# ..         ...        ...             ...            ...                ...
# 338     Gentoo     Biscoe            47.2           13.7              214.0
# 340     Gentoo     Biscoe            46.8           14.3              215.0
# 341     Gentoo     Biscoe            50.4           15.7              222.0
# 342     Gentoo     Biscoe            45.2           14.8              212.0
# 343     Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 95        4300.0    Male
# ...

# %%
df[df['flipper_length_mm'] >= 206.5][df['bill_length_mm'] < 43.35]
# Out:
# C:\Users\abdu\AppData\Local\Temp\ipykernel_11388\4291647136.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['flipper_length_mm'] >= 206.5][df['bill_length_mm'] < 43.35]
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 95   Adelie   Dream            40.8           18.9              208.0
# 228  Gentoo  Biscoe            43.3           13.4              209.0
# 230  Gentoo  Biscoe            40.9           13.7              214.0
# 236  Gentoo  Biscoe            42.0           13.5              210.0
# 244  Gentoo  Biscoe            42.9           13.1              215.0
# 251  Gentoo  Biscoe            42.8           14.2              209.0
# 256  Gentoo  Biscoe            42.6           13.7              213.0
# 260  Gentoo  Biscoe            42.7           13.7              208.0
# 278  Gentoo  Biscoe            43.2           14.5              208.0
# ...
